# %%
# frequency distribution of tokens in T1 including stopwords
import string
from nltk import FreqDist
from nltk.corpus import stopwords
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# load data
filename = 'C:/Users/admin/NLPProject/T1.txt'
file = open(filename, encoding='utf-8')
text = file.read()
file.close()

# split into words
from nltk.tokenize import word_tokenize
tokens = word_tokenize(text)
# convert to lower case
tokens = [w.lower() for w in tokens]
remove_these = set( list(string.punctuation) + list(string.digits))
filtered_text = [w for w in tokens if not w in remove_these]
# remove remaining tokens that are not alphabetic
filtered_text = [word for word in filtered_text if word.isalpha()]
## Creating FreqDist  keeping the 30 most common tokens
all_fdist = FreqDist(filtered_text).most_common(30)
all_fdist = pd.Series(dict(all_fdist))
fig, ax = plt.subplots(figsize=(15,10))
plt.title('Frequency Distribution')
plt.ylabel('Frequency')
plt.xlabel('Word')
all_plot = sns.barplot(x=all_fdist.index, y=all_fdist.values, ax=ax)

# %%
# frequency distribution of tokens in T2 including stopwords
import string
from nltk import FreqDist
from nltk.corpus import stopwords
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# load data
filename = 'C:/Users/admin/NLPProject/T2.txt'
file = open(filename, encoding='utf-8')
text = file.read()
file.close()

# split into words
from nltk.tokenize import word_tokenize
tokens = word_tokenize(text)
# convert to lower case
tokens = [w.lower() for w in tokens]
remove_these = set( list(string.punctuation) + list(string.digits))
filtered_text = [w for w in tokens if not w in remove_these]
# remove remaining tokens that are not alphabetic
filtered_text = [word for word in filtered_text if word.isalpha()]
## Creating FreqDist  keeping the 30 most common tokens
all_fdist = FreqDist(filtered_text).most_common(30)
all_fdist = pd.Series(dict(all_fdist))
fig, ax = plt.subplots(figsize=(15,10))
plt.title('Frequency Distribution')
plt.ylabel('Frequency')
plt.xlabel('Word')
all_plot = sns.barplot(x=all_fdist.index, y=all_fdist.values, ax=ax)

# %%
# frequency distribution of tokens in T1 excluding stopwords
import string
from nltk import FreqDist
from nltk.corpus import stopwords
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# load data
filename = 'C:/Users/admin/NLPProject/T1.txt'
file = open(filename, encoding='utf-8')
text = file.read()
file.close()

# split into words
from nltk.tokenize import word_tokenize
tokens = word_tokenize(text)
# convert to lower case
tokens = [w.lower() for w in tokens]
remove_these = set(stopwords.words('english') + list(string.punctuation) + list(string.digits))
filtered_text = [w for w in tokens if not w in remove_these]
# remove remaining tokens that are not alphabetic
filtered_text = [word for word in filtered_text if word.isalpha()]
## Creating FreqDist  keeping the 30 most common tokens
all_fdist = FreqDist(filtered_text).most_common(30)
all_fdist = pd.Series(dict(all_fdist))
fig, ax = plt.subplots(figsize=(15,10))
plt.title('Frequency Distribution')
plt.ylabel('Frequency')
plt.xlabel('Word')
all_plot = sns.barplot(x=all_fdist.index, y=all_fdist.values, ax=ax)

# %%
# frequency distribution of tokens in T2 excluding stopwords
import string
from nltk import FreqDist
from nltk.corpus import stopwords
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# load data
filename = 'C:/Users/admin/NLPProject/T2.txt'
file = open(filename, encoding='utf-8')
text = file.read()
file.close()

# split into words
from nltk.tokenize import word_tokenize
tokens = word_tokenize(text)
# convert to lower case
tokens = [w.lower() for w in tokens]
remove_these = set(stopwords.words('english') + list(string.punctuation) + list(string.digits))
filtered_text = [w for w in tokens if not w in remove_these]
# remove remaining tokens that are not alphabetic
filtered_text = [word for word in filtered_text if word.isalpha()]
## Creating FreqDist  keeping the 30 most common tokens
all_fdist = FreqDist(filtered_text).most_common(30)
all_fdist = pd.Series(dict(all_fdist))
fig, ax = plt.subplots(figsize=(15,10))
plt.title('Frequency Distribution')
plt.ylabel('Frequency')
plt.xlabel('Word')
all_plot = sns.barplot(x=all_fdist.index, y=all_fdist.values, ax=ax)

# %%
#Word Cloud of T1 using the token including stop word 
#Load data
filename = 'C:/Users/admin/NLPProject/T1.txt'
file = open(filename, encoding='utf-8')
text = file.read()
file.close()
import string
from nltk import FreqDist
from nltk.corpus import stopwords

# split into words
from nltk.tokenize import word_tokenize
tokens = word_tokenize(text)
# convert to lower case
tokens = [w.lower() for w in tokens]
remove_these = set(list(string.punctuation) + list(string.digits))
filtered_text = [w for w in tokens if not w in remove_these]
# remove remaining tokens that are not alphabetic
filtered_text = [word for word in filtered_text if word.isalpha()]

from collections import Counter
dictionary=Counter(filtered_text)
import matplotlib.pyplot as plt
from wordcloud import WordCloud

cloud = WordCloud(max_font_size=80,colormap="hsv").generate_from_frequencies(dictionary)
plt.figure(figsize=(16,12))
plt.imshow(cloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
#Word Cloud of T2 using the token including stop word 
#Load data
filename = 'C:/Users/admin/NLPProject/T2.txt'
file = open(filename, encoding='utf-8')
text = file.read()
file.close()
import string
from nltk import FreqDist
from nltk.corpus import stopwords

# split into words
from nltk.tokenize import word_tokenize
tokens = word_tokenize(text)
# convert to lower case
tokens = [w.lower() for w in tokens]
remove_these = set(list(string.punctuation) + list(string.digits))
filtered_text = [w for w in tokens if not w in remove_these]
# remove remaining tokens that are not alphabetic
filtered_text = [word for word in filtered_text if word.isalpha()]

from collections import Counter
dictionary=Counter(filtered_text)
import matplotlib.pyplot as plt
from wordcloud import WordCloud

cloud = WordCloud(max_font_size=80,colormap="hsv").generate_from_frequencies(dictionary)
plt.figure(figsize=(16,12))
plt.imshow(cloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
#Word Cloud of T1 using the token excluding stop word 
#Load data
filename = 'C:/Users/admin/NLPProject/T1.txt'
file = open(filename, encoding='utf-8')
text = file.read()
file.close()
import string
from nltk import FreqDist
from nltk.corpus import stopwords

# split into words
from nltk.tokenize import word_tokenize
tokens = word_tokenize(text)
# convert to lower case
tokens = [w.lower() for w in tokens]
remove_these = set(stopwords.words('english') + list(string.punctuation) + list(string.digits))
filtered_text = [w for w in tokens if not w in remove_these]
# remove remaining tokens that are not alphabetic
filtered_text = [word for word in filtered_text if word.isalpha()]

from collections import Counter
dictionary=Counter(filtered_text)
import matplotlib.pyplot as plt
from wordcloud import WordCloud

cloud = WordCloud(max_font_size=80,colormap="hsv").generate_from_frequencies(dictionary)
plt.figure(figsize=(16,12))
plt.imshow(cloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
#Word Cloud of T2 using the token excluding stop word 
#Load data
filename = 'C:/Users/admin/NLPProject/T2.txt'
file = open(filename, encoding='utf-8')
text = file.read()
file.close()
import string
from nltk import FreqDist
from nltk.corpus import stopwords

# split into words
from nltk.tokenize import word_tokenize
tokens = word_tokenize(text)
# convert to lower case
tokens = [w.lower() for w in tokens]
remove_these = set(stopwords.words('english') + list(string.punctuation) + list(string.digits))
filtered_text = [w for w in tokens if not w in remove_these]
# remove remaining tokens that are not alphabetic
filtered_text = [word for word in filtered_text if word.isalpha()]

from collections import Counter
dictionary=Counter(filtered_text)
import matplotlib.pyplot as plt
from wordcloud import WordCloud

cloud = WordCloud(max_font_size=80,colormap="hsv").generate_from_frequencies(dictionary)
plt.figure(figsize=(16,12))
plt.imshow(cloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
# word length including stopwords for T1
filename = 'C:/Users/admin/NLPProject/T1.txt'
file = open(filename, encoding='utf-8')
text = file.read()
file.close()
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

words = text.split()
lengths = {}
for word in words:
    length = len(word)
    if length not in lengths:
        lengths[length] = 1
    else:
        lengths[length] += 1
## Creating FreqDist  keeping the 30 most common tokens
all_fdist = FreqDist(lengths).most_common(30)
all_fdist = pd.Series(dict(all_fdist))
fig, ax = plt.subplots(figsize=(15,10))
plt.title('Frequency Distribution')
plt.ylabel('Frequency')
plt.xlabel('Word length')
all_plot = sns.barplot(x=all_fdist.index, y=all_fdist.values, ax=ax)

# %%
# word length including stopwords for T2
filename = 'C:/Users/admin/NLPProject/T2.txt'
file = open(filename, encoding='utf-8')
text = file.read()
file.close()
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

words = text.split()
lengths = {}
for word in words:
    length = len(word)
    if length not in lengths:
        lengths[length] = 1
    else:
        lengths[length] += 1
## Creating FreqDist  keeping the 30 most common tokens
all_fdist = FreqDist(lengths).most_common(30)
all_fdist = pd.Series(dict(all_fdist))
fig, ax = plt.subplots(figsize=(15,10))
plt.title('Frequency Distribution')
plt.ylabel('Frequency')
plt.xlabel('Word length')
all_plot = sns.barplot(x=all_fdist.index, y=all_fdist.values, ax=ax)

# %%
# after removing stopwords for T1
filename = 'C:/Users/admin/NLPProject/T1.txt'
file = open(filename, encoding='utf-8')
text = file.read()
file.close()
import string
from nltk import FreqDist
from nltk.corpus import stopwords
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# split into words
from nltk.tokenize import word_tokenize
tokens = word_tokenize(text)
# convert to lower case
tokens = [w.lower() for w in tokens]
remove_these = set(stopwords.words('english') + list(string.punctuation) + list(string.digits))
filtered_text = [w for w in tokens if not w in remove_these]
# remove remaining tokens that are not alphabetic
words = [word for word in filtered_text if word.isalpha()]

for word in words:
    length = len(word)
    if length not in lengths:
        lengths[length] = 1
    else:
        lengths[length] += 1
## Creating FreqDist  keeping the 30 most common tokens
all_fdist = FreqDist(lengths).most_common(30)
all_fdist = pd.Series(dict(all_fdist))
fig, ax = plt.subplots(figsize=(15,10))
plt.title('Frequency Distribution')
plt.ylabel('Frequency')
plt.xlabel('Word length')
all_plot = sns.barplot(x=all_fdist.index, y=all_fdist.values, ax=ax)

# %%
# after removing stopwords for T2
filename = 'C:/Users/admin/NLPProject/T2.txt'
file = open(filename, encoding='utf-8')
text = file.read()
file.close()
import string
from nltk import FreqDist
from nltk.corpus import stopwords
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# split into words
from nltk.tokenize import word_tokenize
tokens = word_tokenize(text)
# convert to lower case
tokens = [w.lower() for w in tokens]
remove_these = set(stopwords.words('english') + list(string.punctuation) + list(string.digits))
filtered_text = [w for w in tokens if not w in remove_these]
# remove remaining tokens that are not alphabetic
words = [word for word in filtered_text if word.isalpha()]

for word in words:
    length = len(word)
    if length not in lengths:
        lengths[length] = 1
    else:
        lengths[length] += 1
## Creating FreqDist  keeping the 30 most common tokens
all_fdist = FreqDist(lengths).most_common(30)
all_fdist = pd.Series(dict(all_fdist))
fig, ax = plt.subplots(figsize=(15,10))
plt.title('Frequency Distribution')
plt.ylabel('Frequency')
plt.xlabel('Word length')
all_plot = sns.barplot(x=all_fdist.index, y=all_fdist.values, ax=ax)

# %%
# pos tagging for T1
import nltk
from nltk.corpus import stopwords
nltk.download('averaged_perceptron_tagger')

# load data
filename = 'C:/Users/admin/NLPProject/T1.txt'
file = open(filename, encoding='utf-8')
text = file.read()
file.close()
# split into words
from nltk.tokenize import word_tokenize
tokens = word_tokenize(text)
# convert to lower case
tokens = [w.lower() for w in tokens]
remove_these = set( list(string.punctuation) + list(string.digits))
filtered_text = [w for w in tokens if not w in remove_these]
# remove remaining tokens that are not alphabetic
token1 = [word for word in filtered_text if word.isalpha()]

tagged1=nltk.pos_tag(token1)
tagged1
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [('project', 'NN'),
#  ('gutenberg', 'VBZ'),
#  ('ebook', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('stolen', 'VBN'),
#  ('brain', 'NN'),
#  ('by', 'IN'),
#  ('nicholas', 'JJ'),
#  ('carter', 'NN'),
#  ('this', 'DT'),
#  ('ebook', 'NN'),
#  ('is', 'VBZ'),
#  ('for', 'IN'),
#  ('the', 'DT'),
#  ('use', 'NN'),
#  ('of', 'IN'),
#  ('anyone', 'NN'),
#  ('anywhere', 'RB'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('united', 'JJ'),
#  ('states', 'NNS'),
#  ('and', 'CC'),
#  ('most', 'JJS'),
#  ('other', 'JJ'),
#  ('parts', 'NNS'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('world', 'NN'),
#  ('at', 'IN'),
#  ('no', 'DT'),
#  ('cost', 'NN'),
#  ('and', 'CC'),
#  ('with', 'IN'),
#  ('almost', 'RB'),
#  ('no', 'DT'),
#  ('restrictions', 'NNS'),
#  ('whatsoever', 'IN'),
#  ('you', 'PRP'),
#  ('may', 'MD'),
#  ('copy', 'VB'),
#  ('it', 'PRP'),
#  ('give', 'VB'),
#  ('it', 'PRP'),
#  ('away', 'RB'),
#  ('or', 'CC'),
#  ('it', 'PRP'),
#  ('under', 'IN'),
#  ('the', 'DT'),
#  ('terms', 'NNS'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('project', 'NN'),
#  ('gutenberg', 'NN'),
#  ('license', 'NN'),
#  ('included', 'VBD'),
#  ('with', 'IN'),
#  ('this', 'DT'),
#  ('ebook', 'NN'),
#  ('or', 'CC'),
#  ('online', 'NN'),
#  ('at', 'IN'),
#  ('if', 'IN'),
#  ('you', 'PRP'),
#  ('are', 'VBP'),
#  ('not', 'RB'),
#  ('located', 'VBN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('united', 'JJ'),
#  ('states', 'NNS'),
#  ('you', 'PRP'),
#  ('will', 'MD'),
#  ('have', 'VB'),
#  ('to', 'TO'),
#  ('check', 'VB'),
#  ('the', 'DT'),
#  ('laws', 'NNS'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('country', 'NN'),
#  ('where', 'WRB'),
#  ('you', 'PRP'),
#  ('are', 'VBP'),
#  ('located', 'VBN'),
#  ('before', 'IN'),
#  ('using', 'VBG'),
#  ('this', 'DT'),
#  ('ebook', 'NN'),
#  ('title', 'VBZ'),
#  ('the', 'DT'),
#  ('stolen', 'VBN'),
#  ('brain', 'NN'),
#  ('a', 'DT'),
#  ('wonderful', 'JJ'),
#  ('crime', 'NN'),
#  ('author', 'NN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'NN'),
#  ('release', 'NN'),
#  ('date', 'NN'),
#  ('november', 'NNP'),
#  ('ebook', 'NN'),
#  ('language', 'NN'),
#  ('english', 'JJ'),
#  ('character', 'NN'),
#  ('set', 'VBN'),
#  ('encoding', 'VBG'),
#  ('produced', 'VBN'),
#  ('by', 'IN'),
#  ('david', 'NN'),
#  ('edwards', 'NNS'),
#  ('chuck', 'VBP'),
#  ('greif', 'NN'),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('online', 'NN'),
#  ('distributed', 'VBD'),
#  ('proofreading', 'VBG'),
#  ('team', 'NN'),
#  ('at', 'IN'),
#  ('https', 'JJ'),
#  ('start', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('project', 'NN'),
#  ('gutenberg', 'NN'),
#  ('ebook', 'VBD'),
#  ('the', 'DT'),
#  ('stolen', 'VBN'),
#  ('brain', 'NN'),
#  ('nick', 'JJ'),
#  ('carter', 'NN'),
#  ('stories', 'NNS'),
#  ('new', 'JJ'),
#  ('magnet', 'JJ'),
#  ('library', 'JJ'),
#  ('price', 'NN'),
#  ('fifteen', 'NN'),
#  ('cents', 'NNS'),
#  ('a', 'DT'),
#  ('dull', 'JJ'),
#  ('book', 'NN'),
#  ('in', 'IN'),
#  ('this', 'DT'),
#  ('nick', 'JJ'),
#  ('carter', 'NN'),
#  ('stands', 'NNS'),
#  ('for', 'IN'),
#  ('an', 'DT'),
#  ('interesting', 'JJ'),
#  ('detective', 'JJ'),
#  ('story', 'NN'),
#  ('the', 'DT'),
#  ('fact', 'NN'),
#  ('that', 'IN'),
#  ('the', 'DT'),
#  ('books', 'NNS'),
#  ('in', 'IN'),
#  ('this', 'DT'),
#  ('line', 'NN'),
#  ('are', 'VBP'),
#  ('so', 'RB'),
#  ('uniformly', 'RB'),
#  ('good', 'JJ'),
#  ('is', 'VBZ'),
#  ('entirely', 'RB'),
#  ('due', 'JJ'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('work', 'NN'),
#  ('of', 'IN'),
#  ('a', 'DT'),
#  ('specialist', 'NN'),
#  ('the', 'DT'),
#  ('man', 'NN'),
#  ('who', 'WP'),
#  ('wrote', 'VBD'),
#  ('these', 'DT'),
#  ('stories', 'NNS'),
#  ('produced', 'VBD'),
#  ('no', 'DT'),
#  ('other', 'JJ'),
#  ('type', 'NN'),
#  ('of', 'IN'),
#  ('fiction', 'NN'),
#  ('his', 'PRP$'),
#  ('mind', 'NN'),
#  ('was', 'VBD'),
#  ('concentrated', 'VBN'),
#  ('upon', 'IN'),
#  ('the', 'DT'),
#  ('creation', 'NN'),
#  ('of', 'IN'),
#  ('new', 'JJ'),
#  ('plots', 'NNS'),
#  ('and', 'CC'),
#  ('situations', 'NNS'),
#  ('in', 'IN'),
#  ('which', 'WDT'),
#  ('his', 'PRP$'),
#  ('hero', 'NN'),
#  ('emerged', 'VBD'),
#  ('triumphantly', 'RB'),
#  ('from', 'IN'),
#  ('all', 'DT'),
#  ('sorts', 'NNS'),
#  ('of', 'IN'),
#  ('trouble', 'NN'),
#  ('and', 'CC'),
#  ('landed', 'VBD'),
#  ('the', 'DT'),
#  ('criminal', 'NN'),
#  ('just', 'RB'),
#  ('where', 'WRB'),
#  ('he', 'PRP'),
#  ('should', 'MD'),
#  ('be', 'VB'),
#  ('behind', 'IN'),
#  ('the', 'DT'),
#  ('bars', 'NNS'),
#  ('the', 'DT'),
#  ('author', 'NN'),
#  ('of', 'IN'),
#  ('these', 'DT'),
#  ('stories', 'NNS'),
#  ('knew', 'VBD'),
#  ('more', 'RBR'),
#  ('about', 'IN'),
#  ('writing', 'VBG'),
#  ('detective', 'JJ'),
#  ('stories', 'NNS'),
#  ('than', 'IN'),
#  ('any', 'DT'),
#  ('other', 'JJ'),
#  ('single', 'JJ'),
#  ('person', 'NN'),
#  ('following', 'VBG'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('list', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('best', 'JJS'),
#  ('nick', 'JJ'),
#  ('carter', 'NN'),
#  ('stories', 'NNS'),
#  ('they', 'PRP'),
#  ('have', 'VBP'),
#  ('been', 'VBN'),
#  ('selected', 'VBN'),
#  ('with', 'IN'),
#  ('extreme', 'JJ'),
#  ('care', 'NN'),
#  ('and', 'CC'),
#  ('we', 'PRP'),
#  ('unhesitatingly', 'RB'),
#  ('recommend', 'VBP'),
#  ('each', 'DT'),
#  ('of', 'IN'),
#  ('them', 'PRP'),
#  ('as', 'IN'),
#  ('being', 'VBG'),
#  ('fully', 'RB'),
#  ('as', 'RB'),
#  ('interesting', 'JJ'),
#  ('as', 'IN'),
#  ('any', 'DT'),
#  ('detective', 'JJ'),
#  ('story', 'NN'),
#  ('between', 'IN'),
#  ('cloth', 'NN'),
#  ('covers', 'VBZ'),
#  ('which', 'WDT'),
#  ('sells', 'VBZ'),
#  ('at', 'IN'),
#  ('ten', 'NN'),
#  ('times', 'VBZ'),
#  ('the', 'DT'),
#  ('price', 'NN'),
#  ('if', 'IN'),
#  ('you', 'PRP'),
#  ('do', 'VBP'),
#  ('not', 'RB'),
#  ('know', 'VB'),
#  ('nick', 'JJ'),
#  ('carter', 'NN'),
#  ('buy', 'VB'),
#  ('a', 'DT'),
#  ('copy', 'NN'),
#  ('of', 'IN'),
#  ('any', 'DT'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('new', 'JJ'),
#  ('magnet', 'NN'),
#  ('library', 'NN'),
#  ('books', 'NNS'),
#  ('and', 'CC'),
#  ('get', 'VB'),
#  ('acquainted', 'VBN'),
#  ('he', 'PRP'),
#  ('will', 'MD'),
#  ('surprise', 'VB'),
#  ('and', 'CC'),
#  ('delight', 'VB'),
#  ('you', 'PRP'),
#  ('titles', 'NNS'),
#  ('always', 'RB'),
#  ('in', 'IN'),
#  ('wanted', 'VBD'),
#  ('a', 'DT'),
#  ('clew', 'NN'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'VBP'),
#  ('a', 'DT'),
#  ('tangled', 'JJ'),
#  ('skein', 'NN'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'VBP'),
#  ('the', 'DT'),
#  ('bullion', 'NN'),
#  ('mystery', 'NN'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'VBP'),
#  ('the', 'DT'),
#  ('man', 'NN'),
#  ('of', 'IN'),
#  ('riddles', 'NNS'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'VBP'),
#  ('a', 'DT'),
#  ('miscarriage', 'NN'),
#  ('of', 'IN'),
#  ('justice', 'NN'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'VBP'),
#  ('the', 'DT'),
#  ('gloved', 'JJ'),
#  ('hand', 'NN'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'NN'),
#  ('spoilers', 'NNS'),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('spoils', 'NNS'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'VBP'),
#  ('the', 'DT'),
#  ('deeper', 'JJ'),
#  ('game', 'NN'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'NN'),
#  ('bolts', 'NNS'),
#  ('from', 'IN'),
#  ('blue', 'JJ'),
#  ('skies', 'NNS'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'NN'),
#  ('unseen', 'JJ'),
#  ('foes', 'NNS'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'NN'),
#  ('knaves', 'NNS'),
#  ('in', 'IN'),
#  ('high', 'JJ'),
#  ('places', 'NNS'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'VBP'),
#  ('the', 'DT'),
#  ('microbe', 'NN'),
#  ('of', 'IN'),
#  ('crime', 'NN'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'NN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('toils', 'NNS'),
#  ('of', 'IN'),
#  ('fear', 'NN'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'VBP'),
#  ('a', 'DT'),
#  ('heritage', 'NN'),
#  ('of', 'IN'),
#  ('trouble', 'NN'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'NN'),
#  ('called', 'VBN'),
#  ('to', 'TO'),
#  ('account', 'VB'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'VBP'),
#  ('the', 'DT'),
#  ('just', 'RB'),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('unjust', 'JJ'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'NN'),
#  ('instinct', 'NN'),
#  ('at', 'IN'),
#  ('fault', 'NN'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'VBP'),
#  ('a', 'DT'),
#  ('rogue', 'NN'),
#  ('worth', 'IN'),
#  ('trapping', 'VBG'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'VBP'),
#  ('a', 'DT'),
#  ('woman', 'NN'),
#  ('s', 'JJ'),
#  ('hand', 'NN'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'VBP'),
#  ('a', 'DT'),
#  ('network', 'NN'),
#  ('of', 'IN'),
#  ('crime', 'NN'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'NN'),
#  ('at', 'IN'),
#  ('thompson', 'NN'),
#  ('s', 'NN'),
#  ('ranch', 'NN'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'VBP'),
#  ('the', 'DT'),
#  ('crossed', 'JJ'),
#  ('needles', 'NNS'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'VBP'),
#  ('the', 'DT'),
#  ('diamond', 'NN'),
#  ('mine', 'NN'),
#  ('case', 'NN'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'NN'),
#  ('blood', 'NN'),
#  ('will', 'MD'),
#  ('tell', 'VB'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'VBP'),
#  ('an', 'DT'),
#  ('accidental', 'JJ'),
#  ('password', 'NN'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'VBP'),
#  ('the', 'DT'),
#  ('crook', 'NN'),
#  ('s', 'NN'),
#  ('bauble', 'JJ'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'RB'),
#  ('two', 'CD'),
#  ('plus', 'CC'),
#  ('two', 'CD'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'VBP'),
#  ('the', 'DT'),
#  ('yellow', 'JJ'),
#  ('label', 'NN'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'VBP'),
#  ('the', 'DT'),
#  ('clever', 'NN'),
#  ('celestial', 'NN'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'VBP'),
#  ('the', 'DT'),
#  ('amphitheater', 'NN'),
#  ('plot', 'NN'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'NN'),
#  ('gideon', 'NN'),
#  ('drexel', 'NN'),
#  ('s', 'NN'),
#  ('millions', 'NNS'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'JJ'),
#  ('death', 'NN'),
#  ('in', 'IN'),
#  ('life', 'NN'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'VBP'),
#  ('a', 'DT'),
#  ('stolen', 'VBN'),
#  ('identity', 'NN'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'JJ'),
#  ('evidence', 'NN'),
#  ('by', 'IN'),
#  ('telephone', 'NN'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'VBP'),
#  ('the', 'DT'),
#  ('twelve', 'NN'),
#  ('tin', 'NN'),
#  ('boxes', 'NNS'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'NN'),
#  ('clew', 'NN'),
#  ('against', 'IN'),
#  ('clew', 'NN'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'NN'),
#  ('lady', 'NN'),
#  ('velvet', 'NN'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'JJ'),
#  ('playing', 'VBG'),
#  ('a', 'DT'),
#  ('bold', 'JJ'),
#  ('game', 'NN'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'VBP'),
#  ('a', 'DT'),
#  ('dead', 'JJ'),
#  ('man', 'NN'),
#  ('s', 'NN'),
#  ('grip', 'NN'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'NN'),
#  ('snarled', 'VBN'),
#  ('identities', 'NNS'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'VBP'),
#  ('a', 'DT'),
#  ('deposit', 'NN'),
#  ('vault', 'NN'),
#  ('puzzle', 'NN'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'VBP'),
#  ('the', 'DT'),
#  ('crescent', 'NN'),
#  ('brotherhood', 'NN'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'VBP'),
#  ('the', 'DT'),
#  ('stolen', 'JJ'),
#  ('pay', 'NN'),
#  ('train', 'NN'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'VBP'),
#  ('the', 'DT'),
#  ('sea', 'NN'),
#  ('fox', 'NN'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'RB'),
#  ('wanted', 'VBN'),
#  ('by', 'IN'),
#  ('two', 'CD'),
#  ('clients', 'NNS'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'VBP'),
#  ('the', 'DT'),
#  ('van', 'NN'),
#  ('alstine', 'NN'),
#  ('case', 'NN'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'RB'),
#  ('check', 'VBP'),
#  ('no', 'DT'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'JJ'),
#  ('partners', 'NNS'),
#  ('in', 'IN'),
#  ('peril', 'NN'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'NN'),
#  ('nick', 'VBP'),
#  ('carter', 'NN'),
#  ('s', 'NN'),
#  ('clever', 'NN'),
#  ('protégé', 'NN'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'VBP'),
#  ('the', 'DT'),
#  ('sign', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('crossed', 'JJ'),
#  ('knives', 'NNS'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'VBP'),
#  ('the', 'DT'),
#  ('man', 'NN'),
#  ('who', 'WP'),
#  ('vanished', 'VBD'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'VBP'),
#  ('a', 'DT'),
#  ('battle', 'NN'),
#  ('for', 'IN'),
#  ('the', 'DT'),
#  ('right', 'NN'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'VBP'),
#  ('a', 'DT'),
#  ('game', 'NN'),
#  ('of', 'IN'),
#  ('craft', 'NN'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'NN'),
#  ('nick', 'VBP'),
#  ('carter', 'NN'),
#  ('s', 'NN'),
#  ('retainer', 'NN'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'NN'),
#  ('caught', 'VBN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('toils', 'NNS'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'VBP'),
#  ('a', 'DT'),
#  ('broken', 'JJ'),
#  ('bond', 'NN'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'VBP'),
#  ('the', 'DT'),
#  ('crime', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('french', 'JJ'),
#  ('café', 'NN'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'VBP'),
#  ('the', 'DT'),
#  ('man', 'NN'),
#  ('who', 'WP'),
#  ('stole', 'VBD'),
#  ('millions', 'NNS'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'VBP'),
#  ('the', 'DT'),
#  ('twelve', 'NN'),
#  ('wise', 'NN'),
#  ('men', 'NNS'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'JJ'),
#  ('hidden', 'VBN'),
#  ('foes', 'NNS'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'VBP'),
#  ('a', 'DT'),
#  ('gamblers', 'NNS'),
#  ('syndicate', 'NN'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'VBP'),
#  ('a', 'DT'),
#  ('chance', 'NN'),
#  ('discovery', 'NN'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'NN'),
#  ('among', 'IN'),
#  ('the', 'DT'),
#  ('counterfeiters', 'NNS'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'VBP'),
#  ('a', 'DT'),
#  ('threefold', 'JJ'),
#  ('disappearance', 'NN'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'NN'),
#  ('at', 'IN'),
#  ('odds', 'NNS'),
#  ('with', 'IN'),
#  ('scotland', 'NN'),
#  ('yard', 'NN'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'VBP'),
#  ('a', 'DT'),
#  ('princess', 'NN'),
#  ('of', 'IN'),
#  ('crime', 'NN'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'NN'),
#  ('found', 'VBN'),
#  ('on', 'IN'),
#  ('the', 'DT'),
#  ('beach', 'NN'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'VBP'),
#  ('a', 'DT'),
#  ('spinner', 'NN'),
#  ('of', 'IN'),
#  ('death', 'NN'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'VBP'),
#  ('the', 'DT'),
#  ('detective', 'JJ'),
#  ('s', 'NN'),
#  ('pretty', 'RB'),
#  ('neighbor', 'JJ'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'VBP'),
#  ('a', 'DT'),
#  ('bogus', 'NN'),
#  ('clew', 'NN'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'VBP'),
#  ('the', 'DT'),
#  ('puzzle', 'NN'),
#  ('of', 'IN'),
#  ('five', 'CD'),
#  ('pistols', 'NNS'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'VBP'),
#  ('the', 'DT'),
#  ('secret', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('marble', 'JJ'),
#  ('mantel', 'NN'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'VBP'),
#  ('a', 'DT'),
#  ('bite', 'NN'),
#  ('of', 'IN'),
#  ('an', 'DT'),
#  ('apple', 'NN'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'VBP'),
#  ('a', 'DT'),
#  ('triple', 'NN'),
#  ('crime', 'NN'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'VBP'),
#  ('the', 'DT'),
#  ('stolen', 'JJ'),
#  ('race', 'NN'),
#  ('horse', 'NN'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'NN'),
#  ('wildfire', 'NN'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'VBP'),
#  ('a', 'DT'),
#  ('personal', 'JJ'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'VBP'),
#  ('the', 'DT'),
#  ('finger', 'NN'),
#  ('of', 'IN'),
#  ('suspicion', 'NN'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'VBP'),
#  ('the', 'DT'),
#  ('crimson', 'NN'),
#  ('clew', 'NN'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'NN'),
#  ('nick', 'VBP'),
#  ('carter', 'NN'),
#  ('down', 'RP'),
#  ('east', 'RB'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'VBP'),
#  ('the', 'DT'),
#  ('chain', 'NN'),
#  ('of', 'IN'),
#  ('clews', 'NNS'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'VBP'),
#  ('a', 'DT'),
#  ('victim', 'NN'),
#  ('of', 'IN'),
#  ('circumstances', 'NNS'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'RB'),
#  ('brought', 'VBD'),
#  ('to', 'TO'),
#  ('bay', 'VB'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'VBP'),
#  ('the', 'DT'),
#  ('dynamite', 'NN'),
#  ('trap', 'NN'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'VBP'),
#  ('a', 'DT'),
#  ('scrap', 'NN'),
#  ('of', 'IN'),
#  ('black', 'JJ'),
#  ('lace', 'NN'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'VBP'),
#  ('the', 'DT'),
#  ('woman', 'NN'),
#  ('of', 'IN'),
#  ('evil', 'NN'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'VBP'),
#  ('a', 'DT'),
#  ('legacy', 'NN'),
#  ('of', 'IN'),
#  ('hate', 'NN'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'VBP'),
#  ('a', 'DT'),
#  ('trusted', 'JJ'),
#  ('rogue', 'NN'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'JJ'),
#  ('man', 'NN'),
#  ('against', 'IN'),
#  ('man', 'NN'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'VBP'),
#  ('the', 'DT'),
#  ('demons', 'NNS'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('night', 'NN'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'VBP'),
#  ('the', 'DT'),
#  ('brotherhood', 'NN'),
#  ('of', 'IN'),
#  ('death', 'NN'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'NN'),
#  ('at', 'IN'),
#  ('the', 'DT'),
#  ('knife', 'NN'),
#  ('s', 'VBD'),
#  ('point', 'NN'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'VBP'),
#  ('a', 'DT'),
#  ('cry', 'NN'),
#  ('for', 'IN'),
#  ('help', 'NN'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'VBP'),
#  ('a', 'DT'),
#  ('stroke', 'NN'),
#  ('of', 'IN'),
#  ('policy', 'NN'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'RB'),
#  ('hounded', 'VBD'),
#  ('to', 'TO'),
#  ('death', 'NN'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'VBP'),
#  ('a', 'DT'),
#  ('bargain', 'NN'),
#  ('in', 'IN'),
#  ('crime', 'NN'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'VBP'),
#  ('the', 'DT'),
#  ('fatal', 'JJ'),
#  ('prescription', 'NN'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'VBP'),
#  ('the', 'DT'),
#  ('man', 'NN'),
#  ('of', 'IN'),
#  ('iron', 'NN'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'VBP'),
#  ('an', 'DT'),
#  ('amazing', 'JJ'),
#  ('scoundrel', 'NN'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'VBP'),
#  ('the', 'DT'),
#  ('chain', 'NN'),
#  ('of', 'IN'),
#  ('evidence', 'NN'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'NN'),
#  ('paid', 'VBN'),
#  ('with', 'IN'),
#  ('death', 'NN'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'VBP'),
#  ('a', 'DT'),
#  ('fight', 'NN'),
#  ('for', 'IN'),
#  ('a', 'DT'),
#  ('throne', 'NN'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'VBP'),
#  ('the', 'DT'),
#  ('woman', 'NN'),
#  ('of', 'IN'),
#  ('steel', 'NN'),
#  ('by', 'IN'),
#  ('nicholas', 'NNS'),
#  ('carter', 'VBP'),
#  ...]

# %%
# pos tagging for T2
import nltk
from nltk.corpus import stopwords
nltk.download('averaged_perceptron_tagger')

# load data
filename = 'C:/Users/admin/NLPProject/T2.txt'
file = open(filename, encoding='utf-8')
text = file.read()
file.close()
# split into words
from nltk.tokenize import word_tokenize
tokens = word_tokenize(text)
# convert to lower case
tokens = [w.lower() for w in tokens]
remove_these = set( list(string.punctuation) + list(string.digits))
filtered_text = [w for w in tokens if not w in remove_these]
# remove remaining tokens that are not alphabetic
token1 = [word for word in filtered_text if word.isalpha()]

tagged2=nltk.pos_tag(token1)
tagged2
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [('project', 'NN'),
#  ('gutenberg', 'VBZ'),
#  ('ebook', 'NN'),
#  ('of', 'IN'),
#  ('nick', 'JJ'),
#  ('carter', 'NN'),
#  ('stories', 'VBZ'),
#  ('no', 'DT'),
#  ('dec', 'NN'),
#  ('oct', 'RB'),
#  ('by', 'IN'),
#  ('nick', 'JJ'),
#  ('carter', 'NN'),
#  ('this', 'DT'),
#  ('ebook', 'NN'),
#  ('is', 'VBZ'),
#  ('for', 'IN'),
#  ('the', 'DT'),
#  ('use', 'NN'),
#  ('of', 'IN'),
#  ('anyone', 'NN'),
#  ('anywhere', 'RB'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('united', 'JJ'),
#  ('states', 'NNS'),
#  ('and', 'CC'),
#  ('most', 'JJS'),
#  ('other', 'JJ'),
#  ('parts', 'NNS'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('world', 'NN'),
#  ('at', 'IN'),
#  ('no', 'DT'),
#  ('cost', 'NN'),
#  ('and', 'CC'),
#  ('with', 'IN'),
#  ('almost', 'RB'),
#  ('no', 'DT'),
#  ('restrictions', 'NNS'),
#  ('whatsoever', 'IN'),
#  ('you', 'PRP'),
#  ('may', 'MD'),
#  ('copy', 'VB'),
#  ('it', 'PRP'),
#  ('give', 'VB'),
#  ('it', 'PRP'),
#  ('away', 'RB'),
#  ('or', 'CC'),
#  ('it', 'PRP'),
#  ('under', 'IN'),
#  ('the', 'DT'),
#  ('terms', 'NNS'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('project', 'NN'),
#  ('gutenberg', 'NN'),
#  ('license', 'NN'),
#  ('included', 'VBD'),
#  ('with', 'IN'),
#  ('this', 'DT'),
#  ('ebook', 'NN'),
#  ('or', 'CC'),
#  ('online', 'NN'),
#  ('at', 'IN'),
#  ('if', 'IN'),
#  ('you', 'PRP'),
#  ('are', 'VBP'),
#  ('not', 'RB'),
#  ('located', 'VBN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('united', 'JJ'),
#  ('states', 'NNS'),
#  ('you', 'PRP'),
#  ('will', 'MD'),
#  ('have', 'VB'),
#  ('to', 'TO'),
#  ('check', 'VB'),
#  ('the', 'DT'),
#  ('laws', 'NNS'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('country', 'NN'),
#  ('where', 'WRB'),
#  ('you', 'PRP'),
#  ('are', 'VBP'),
#  ('located', 'VBN'),
#  ('before', 'IN'),
#  ('using', 'VBG'),
#  ('this', 'DT'),
#  ('ebook', 'NN'),
#  ('title', 'NN'),
#  ('nick', 'JJ'),
#  ('carter', 'NN'),
#  ('stories', 'VBZ'),
#  ('no', 'DT'),
#  ('dec', 'NN'),
#  ('oct', 'RB'),
#  ('won', 'VBN'),
#  ('by', 'IN'),
#  ('magic', 'NN'),
#  ('on', 'IN'),
#  ('a', 'DT'),
#  ('dark', 'JJ'),
#  ('stage', 'NN'),
#  ('author', 'NN'),
#  ('nick', 'JJ'),
#  ('carter', 'NN'),
#  ('roland', 'NN'),
#  ('ashford', 'NN'),
#  ('phillips', 'VBZ'),
#  ('editor', 'NN'),
#  ('chickering', 'VBG'),
#  ('carter', 'NN'),
#  ('release', 'NN'),
#  ('date', 'NN'),
#  ('november', 'NNP'),
#  ('ebook', 'NN'),
#  ('language', 'NN'),
#  ('english', 'JJ'),
#  ('character', 'NN'),
#  ('set', 'VBN'),
#  ('encoding', 'VBG'),
#  ('produced', 'VBN'),
#  ('by', 'IN'),
#  ('david', 'NN'),
#  ('edwards', 'NNS'),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('online', 'NN'),
#  ('distributed', 'VBD'),
#  ('proofreading', 'VBG'),
#  ('team', 'NN'),
#  ('at', 'IN'),
#  ('https', 'JJ'),
#  ('northern', 'JJ'),
#  ('illinois', 'NN'),
#  ('university', 'NN'),
#  ('digital', 'JJ'),
#  ('library', 'JJ'),
#  ('start', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('project', 'NN'),
#  ('gutenberg', 'NN'),
#  ('ebook', 'NN'),
#  ('nick', 'JJ'),
#  ('carter', 'NN'),
#  ('stories', 'VBZ'),
#  ('no', 'DT'),
#  ('dec', 'NN'),
#  ('oct', 'RB'),
#  ('nick', 'JJ'),
#  ('carter', 'NN'),
#  ('stories', 'NNS'),
#  ('weekly', 'RB'),
#  ('entered', 'VBD'),
#  ('as', 'IN'),
#  ('matter', 'NN'),
#  ('at', 'IN'),
#  ('the', 'DT'),
#  ('new', 'JJ'),
#  ('york', 'NN'),
#  ('post', 'NN'),
#  ('office', 'NN'),
#  ('street', 'NN'),
#  ('smith', 'VBP'),
#  ('seventh', 'JJ'),
#  ('new', 'JJ'),
#  ('street', 'NN'),
#  ('smith', 'NN'),
#  ('smith', 'NN'),
#  ('and', 'CC'),
#  ('smith', 'NN'),
#  ('terms', 'NNS'),
#  ('to', 'TO'),
#  ('nick', 'VB'),
#  ('carter', 'NN'),
#  ('stories', 'NNS'),
#  ('mail', 'VBP'),
#  ('subscribers', 'NNS'),
#  ('single', 'JJ'),
#  ('copies', 'NNS'),
#  ('or', 'CC'),
#  ('back', 'JJ'),
#  ('numbers', 'NNS'),
#  ('each', 'DT'),
#  ('months', 'NNS'),
#  ('months', 'NNS'),
#  ('months', 'NNS'),
#  ('one', 'CD'),
#  ('year', 'NN'),
#  ('copies', 'VBZ'),
#  ('one', 'CD'),
#  ('year', 'NN'),
#  ('copy', 'NN'),
#  ('two', 'CD'),
#  ('years', 'NNS'),
#  ('to', 'TO'),
#  ('send', 'VB'),
#  ('by', 'IN'),
#  ('or', 'CC'),
#  ('express', 'VB'),
#  ('money', 'NN'),
#  ('order', 'NN'),
#  ('registered', 'VBD'),
#  ('letter', 'NN'),
#  ('bank', 'NN'),
#  ('check', 'NN'),
#  ('or', 'CC'),
#  ('draft', 'NN'),
#  ('at', 'IN'),
#  ('our', 'PRP$'),
#  ('risk', 'NN'),
#  ('at', 'IN'),
#  ('your', 'PRP$'),
#  ('own', 'JJ'),
#  ('risk', 'NN'),
#  ('if', 'IN'),
#  ('sent', 'VBN'),
#  ('by', 'IN'),
#  ('currency', 'NN'),
#  ('coin', 'NN'),
#  ('or', 'CC'),
#  ('postage', 'NN'),
#  ('stamps', 'NNS'),
#  ('in', 'IN'),
#  ('ordinary', 'JJ'),
#  ('letter', 'NN'),
#  ('receipt', 'NN'),
#  ('of', 'IN'),
#  ('your', 'PRP$'),
#  ('remittance', 'NN'),
#  ('is', 'VBZ'),
#  ('acknowledged', 'VBN'),
#  ('by', 'IN'),
#  ('proper', 'JJ'),
#  ('change', 'NN'),
#  ('of', 'IN'),
#  ('number', 'NN'),
#  ('on', 'IN'),
#  ('your', 'PRP$'),
#  ('label', 'NN'),
#  ('if', 'IN'),
#  ('not', 'RB'),
#  ('correct', 'VB'),
#  ('you', 'PRP'),
#  ('have', 'VBP'),
#  ('not', 'RB'),
#  ('been', 'VBN'),
#  ('properly', 'RB'),
#  ('credited', 'VBN'),
#  ('and', 'CC'),
#  ('should', 'MD'),
#  ('let', 'VB'),
#  ('us', 'PRP'),
#  ('know', 'VB'),
#  ('at', 'IN'),
#  ('once', 'RB'),
#  ('no', 'DT'),
#  ('new', 'JJ'),
#  ('york', 'NN'),
#  ('march', 'NN'),
#  ('price', 'NN'),
#  ('five', 'CD'),
#  ('cents', 'NNS'),
#  ('won', 'VBN'),
#  ('by', 'IN'),
#  ('magic', 'NN'),
#  ('or', 'CC'),
#  ('nick', 'JJ'),
#  ('carter', 'NN'),
#  ('s', 'VBP'),
#  ('mysterious', 'JJ'),
#  ('ear', 'NN'),
#  ('edited', 'VBN'),
#  ('by', 'IN'),
#  ('chickering', 'VBG'),
#  ('carter', 'NN'),
#  ('chapter', 'NN'),
#  ('i', 'VBP'),
#  ('the', 'DT'),
#  ('coming', 'VBG'),
#  ('of', 'IN'),
#  ('jai', 'NN'),
#  ('singh', 'JJ'),
#  ('message', 'NN'),
#  ('for', 'IN'),
#  ('carter', 'NN'),
#  ('the', 'DT'),
#  ('wireless', 'NN'),
#  ('operator', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('steamship', 'NN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('linen', 'NN'),
#  ('clothes', 'NNS'),
#  ('and', 'CC'),
#  ('pith', 'NN'),
#  ('helmet', 'NN'),
#  ('ordinarily', 'RB'),
#  ('worn', 'VBN'),
#  ('by', 'IN'),
#  ('white', 'JJ'),
#  ('people', 'NNS'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('tropics', 'NNS'),
#  ('came', 'VBD'),
#  ('along', 'IN'),
#  ('the', 'DT'),
#  ('steamer', 'NN'),
#  ('deck', 'NN'),
#  ('with', 'IN'),
#  ('a', 'DT'),
#  ('slip', 'NN'),
#  ('of', 'IN'),
#  ('paper', 'NN'),
#  ('in', 'IN'),
#  ('his', 'PRP$'),
#  ('hand', 'NN'),
#  ('and', 'CC'),
#  ('stopped', 'VBD'),
#  ('in', 'IN'),
#  ('front', 'NN'),
#  ('of', 'IN'),
#  ('a', 'DT'),
#  ('row', 'NN'),
#  ('of', 'IN'),
#  ('steamer', 'JJ'),
#  ('chairs', 'NNS'),
#  ('under', 'IN'),
#  ('an', 'DT'),
#  ('awning', 'NN'),
#  ('where', 'WRB'),
#  ('s', 'NN'),
#  ('it', 'PRP'),
#  ('from', 'IN'),
#  ('asked', 'VBN'),
#  ('the', 'DT'),
#  ('occupant', 'NN'),
#  ('of', 'IN'),
#  ('one', 'CD'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('chairs', 'NNS'),
#  ('springing', 'VBG'),
#  ('to', 'TO'),
#  ('his', 'PRP$'),
#  ('feet', 'NNS'),
#  ('from', 'IN'),
#  ('shore', 'NN'),
#  ('sir', 'NN'),
#  ('nick', 'JJ'),
#  ('carter', 'NN'),
#  ('who', 'WP'),
#  ('was', 'VBD'),
#  ('holding', 'VBG'),
#  ('out', 'RP'),
#  ('his', 'PRP$'),
#  ('hand', 'NN'),
#  ('even', 'RB'),
#  ('as', 'IN'),
#  ('he', 'PRP'),
#  ('got', 'VBD'),
#  ('up', 'RP'),
#  ('from', 'IN'),
#  ('his', 'PRP$'),
#  ('chair', 'NN'),
#  ('took', 'VBD'),
#  ('the', 'DT'),
#  ('paper', 'NN'),
#  ('quickly', 'RB'),
#  ('and', 'CC'),
#  ('glanced', 'VBN'),
#  ('at', 'IN'),
#  ('the', 'DT'),
#  ('few', 'JJ'),
#  ('words', 'NNS'),
#  ('it', 'PRP'),
#  ('contained', 'VBD'),
#  ('get', 'VB'),
#  ('up', 'RP'),
#  ('to', 'TO'),
#  ('nepal', 'VB'),
#  ('that', 'DT'),
#  ('was', 'VBD'),
#  ('all', 'DT'),
#  ('there', 'EX'),
#  ('was', 'VBD'),
#  ('no', 'DT'),
#  ('signature', 'NN'),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('operator', 'NN'),
#  ('could', 'MD'),
#  ('not', 'RB'),
#  ('say', 'VB'),
#  ('who', 'WP'),
#  ('had', 'VBD'),
#  ('sent', 'VBN'),
#  ('it', 'PRP'),
#  ('it', 'PRP'),
#  ('came', 'VBD'),
#  ('from', 'IN'),
#  ('the', 'DT'),
#  ('main', 'JJ'),
#  ('office', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('telegraph', 'NN'),
#  ('company', 'NN'),
#  ('in', 'IN'),
#  ('calcutta', 'NN'),
#  ('he', 'PRP'),
#  ('explained', 'VBD'),
#  ('the', 'DT'),
#  ('operator', 'NN'),
#  ('told', 'VBD'),
#  ('me', 'PRP'),
#  ('a', 'DT'),
#  ('native', 'JJ'),
#  ('man', 'NN'),
#  ('brought', 'VBD'),
#  ('it', 'PRP'),
#  ('in', 'IN'),
#  ('and', 'CC'),
#  ('paid', 'VBD'),
#  ('for', 'IN'),
#  ('it', 'PRP'),
#  ('he', 'PRP'),
#  ('said', 'VBD'),
#  ('there', 'EX'),
#  ('would', 'MD'),
#  ('be', 'VB'),
#  ('no', 'DT'),
#  ('answer', 'NN'),
#  ('and', 'CC'),
#  ('his', 'PRP$'),
#  ('own', 'JJ'),
#  ('name', 'NN'),
#  ('did', 'VBD'),
#  ('not', 'RB'),
#  ('it', 'PRP'),
#  ('is', 'VBZ'),
#  ('many', 'JJ'),
#  ('years', 'NNS'),
#  ('since', 'IN'),
#  ('i', 'NN'),
#  ('was', 'VBD'),
#  ('in', 'IN'),
#  ('calcutta', 'NN'),
#  ('last', 'JJ'),
#  ('observed', 'JJ'),
#  ('nick', 'JJ'),
#  ('carter', 'NN'),
#  ('to', 'TO'),
#  ('his', 'PRP$'),
#  ('companions', 'NNS'),
#  ('as', 'IN'),
#  ('the', 'DT'),
#  ('operator', 'NN'),
#  ('went', 'VBD'),
#  ('back', 'RB'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('wireless', 'NN'),
#  ('room', 'NN'),
#  ('then', 'RB'),
#  ('it', 'PRP'),
#  ('was', 'VBD'),
#  ('only', 'RB'),
#  ('for', 'IN'),
#  ('a', 'DT'),
#  ('few', 'JJ'),
#  ('days', 'NNS'),
#  ('and', 'CC'),
#  ('i', 'NN'),
#  ('did', 'VBD'),
#  ('not', 'RB'),
#  ('make', 'VB'),
#  ('many', 'JJ'),
#  ('a', 'DT'),
#  ('tall', 'JJ'),
#  ('man', 'NN'),
#  ('whose', 'WP$'),
#  ('square', 'JJ'),
#  ('face', 'NN'),
#  ('and', 'CC'),
#  ('dark', 'JJ'),
#  ('eyes', 'NNS'),
#  ('as', 'RB'),
#  ('well', 'RB'),
#  ('as', 'IN'),
#  ('his', 'PRP$'),
#  ('decided', 'VBD'),
#  ('manner', 'NN'),
#  ('of', 'IN'),
#  ('speech', 'NN'),
#  ('were', 'VBD'),
#  ('all', 'DT'),
#  ('suggestive', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('successful', 'JJ'),
#  ('american', 'JJ'),
#  ('business', 'NN'),
#  ('man', 'NN'),
#  ('got', 'VBD'),
#  ('up', 'RB'),
#  ('from', 'IN'),
#  ('one', 'CD'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('chairs', 'NNS'),
#  ('and', 'CC'),
#  ('looked', 'VBD'),
#  ('over', 'IN'),
#  ('nick', 'JJ'),
#  ('carter', 'NN'),
#  ('s', 'NN'),
#  ('shoulder', 'NN'),
#  ('at', 'IN'),
#  ('the', 'DT'),
#  ('telegram', 'NN'),
#  ('he', 'PRP'),
#  ('still', 'RB'),
#  ('held', 'VBD'),
#  ('open', 'JJ'),
#  ('in', 'IN'),
#  ('one', 'CD'),
#  ('hand', 'NN'),
#  ('get', 'VB'),
#  ('up', 'IN'),
#  ('to', 'TO'),
#  ('nepal', 'JJ'),
#  ('quickly', 'RB'),
#  ('he', 'PRP'),
#  ('read', 'VBD'),
#  ('does', 'VBZ'),
#  ('that', 'IN'),
#  ('mean', 'VB'),
#  ('that', 'IN'),
#  ('my', 'PRP$'),
#  ('boy', 'NN'),
#  ('is', 'VBZ'),
#  ('there', 'RB'),
#  ('do', 'VBP'),
#  ('you', 'PRP'),
#  ('think', 'VB'),
#  ('carter', 'JJR'),
#  ('we', 'PRP'),
#  ('don', 'VBP'),
#  ('t', 'RB'),
#  ('know', 'VBP'),
#  ('that', 'IN'),
#  ('the', 'DT'),
#  ('telegram', 'NN'),
#  ('has', 'VBZ'),
#  ('anything', 'NN'),
#  ('to', 'TO'),
#  ('do', 'VB'),
#  ('with', 'IN'),
#  ('what', 'WDT'),
#  ('has', 'VBZ'),
#  ('brought', 'VBN'),
#  ('us', 'PRP'),
#  ('to', 'TO'),
#  ('india', 'VB'),
#  ('replied', 'VBN'),
#  ('the', 'DT'),
#  ('detective', 'NN'),
#  ('what', 'WP'),
#  ('else', 'RB'),
#  ('could', 'MD'),
#  ('it', 'PRP'),
#  ('be', 'VB'),
#  ('demanded', 'VBN'),
#  ('the', 'DT'),
#  ('other', 'JJ'),
#  ('sharply', 'RB'),
#  ('nick', 'JJ'),
#  ('carter', 'NN'),
#  ('shrugged', 'VBD'),
#  ('his', 'PRP$'),
#  ('shoulders', 'NNS'),
#  ('well', 'RB'),
#  ('arnold', 'IN'),
#  ('you', 'PRP'),
#  ('are', 'VBP'),
#  ('known', 'VBN'),
#  ('here', 'RB'),
#  ('by', 'IN'),
#  ('name', 'NN'),
#  ('at', 'IN'),
#  ('least', 'JJS'),
#  ('as', 'IN'),
#  ('owner', 'NN'),
#  ('of', 'IN'),
#  ('several', 'JJ'),
#  ('ships', 'NNS'),
#  ('including', 'VBG'),
#  ('the', 'DT'),
#  ('and', 'CC'),
#  ('your', 'PRP$'),
#  ('agent', 'NN'),
#  ('william', 'NN'),
#  ('pike', 'NN'),
#  ('has', 'VBZ'),
#  ('vanished', 'VBN'),
#  ('in', 'IN'),
#  ('a', 'DT'),
#  ('rather', 'RB'),
#  ('mysterious', 'JJ'),
#  ('way', 'NN'),
#  ('from', 'IN'),
#  ('your', 'PRP$'),
#  ('office', 'NN'),
#  ('in', 'IN'),
#  ('calcutta', 'NN'),
#  ('perhaps', 'RB'),
#  ('the', 'DT'),
#  ('telegram', 'NN'),
#  ('may', 'MD'),
#  ('be', 'VB'),
#  ('from', 'IN'),
#  ('somebody', 'NN'),
#  ('who', 'WP'),
#  ('has', 'VBZ'),
#  ('seen', 'VBN'),
#  ('pike', 'IN'),
#  ('up', 'IN'),
#  ('in', 'IN'),
#  ('it', 'PRP'),
#  ('may', 'MD'),
#  ('be', 'VB'),
#  ('although', 'IN'),
#  ('i', 'JJ'),
#  ('don', 'VBP'),
#  ('t', 'NN'),
#  ('know', 'VBP'),
#  ('what', 'WP'),
#  ('pike', 'NN'),
#  ('could', 'MD'),
#  ('want', 'VB'),
#  ('up', 'RP'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('back', 'JJ'),
#  ('country', 'NN'),
#  ('away', 'RB'),
#  ('from', 'IN'),
#  ('civilization', 'NN'),
#  ('he', 'PRP'),
#  ('isn', 'VBZ'),
#  ('t', 'NN'),
#  ('that', 'IN'),
#  ('kind', 'NN'),
#  ('of', 'IN'),
#  ('man', 'NN'),
#  ('from', 'IN'),
#  ('what', 'WP'),
#  ('i', 'NN'),
#  ('know', 'VBP'),
#  ('of', 'IN'),
#  ('him', 'PRP'),
#  ('he', 'PRP'),
#  ('is', 'VBZ'),
#  ('more', 'RBR'),
#  ('likely', 'JJ'),
#  ('to', 'TO'),
#  ('go', 'VB'),
#  ('over', 'IN'),
#  ('to', 'TO'),
#  ('europe', 'VB'),
#  ('or', 'CC'),
#  ('if', 'IN'),
#  ('not', 'RB'),
#  ('to', 'TO'),
#  ('get', 'VB'),
#  ('to', 'TO'),
#  ('some', 'DT'),
#  ('other', 'JJ'),
#  ('big', 'JJ'),
#  ('city', 'NN'),
#  ('in', 'IN'),
#  ('india', 'JJ'),
#  ('rangoon', 'NN'),
#  ('lucknow', 'JJ'),
#  ('cawnpur', 'NN'),
#  ('or', 'CC'),
#  ('hyderabad', 'NN'),
#  ('where', 'WRB'),
#  ('he', 'PRP'),
#  ('can', 'MD'),
#  ('spend', 'VB'),
#  ('his', 'PRP$'),
#  ('money', 'NN'),
#  ('and', 'CC'),
#  ('be', 'VB'),
#  ('moderately', 'RB'),
#  ('out', 'IN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('way', 'NN'),
#  ('of', 'IN'),
#  ('at', 'IN'),
#  ('all', 'DT'),
#  ('events', 'NNS'),
#  ('this', 'DT'),
#  ('message', 'NN'),
#  ('agrees', 'VBZ'),
#  ('with', 'IN'),
#  ('our', 'PRP$'),
#  ('own', 'JJ'),
#  ('ideas', 'NNS'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('direction', 'NN'),
#  ('taken', 'VBN'),
#  ('by', 'IN'),
#  ('leslie', 'NN'),
#  ('said', 'VBD'),
#  ('nick', 'JJ'),
#  ('carter', 'NN'),
#  ('jefferson', 'NN'),
#  ('arnold', 'RB'),
#  ('did', 'VBD'),
#  ('not', 'RB'),
#  ('speak', 'VB'),
#  ('for', 'IN'),
#  ('a', 'DT'),
#  ('few', 'JJ'),
#  ('moments', 'NNS'),
#  ('he', 'PRP'),
#  ('was', 'VBD'),
#  ('not', 'RB'),
#  ('a', 'DT'),
#  ('demonstrative', 'JJ'),
#  ('man', 'NN'),
#  ('and', 'CC'),
#  ('although', 'IN'),
#  ('his', 'PRP$'),
#  ('heart', 'NN'),
#  ('was', 'VBD'),
#  ('wrung', 'VBN'),
#  ('by', 'IN'),
#  ('the', 'DT'),
#  ('strange', 'JJ'),
#  ('disappearance', 'NN'),
#  ('of', 'IN'),
#  ('his', 'PRP$'),
#  ('only', 'JJ'),
#  ('son', 'NN'),
#  ('his', 'PRP$'),
#  ('face', 'NN'),
#  ('was', 'VBD'),
#  ('as', 'RB'),
#  ('impassive', 'JJ'),
#  ('as', 'IN'),
#  ('it', 'PRP'),
#  ('generally', 'RB'),
#  ('was', 'VBD'),
#  ('when', 'WRB'),
#  ('putting', 'VBG'),
#  ('through', 'IN'),
#  ('some', 'DT'),
#  ('great', 'JJ'),
#  ('business', 'NN'),
#  ('deal', 'NN'),
#  ('in', 'IN'),
#  ('new', 'JJ'),
#  ('york', 'NN'),
#  ('with', 'IN'),
#  ('perhaps', 'RB'),
#  ('millions', 'NNS'),
#  ('of', 'IN'),
#  ('dollars', 'NNS'),
#  ('involved', 'VBN'),
#  ('here', 'RB'),
#  ('on', 'IN'),
#  ('the', 'DT'),
#  ('deck', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('finest', 'JJS'),
#  ('steamer', 'NN'),
#  ('of', 'IN'),
#  ('his', 'PRP$'),
#  ('fleet', 'NN'),
#  ('of', 'IN'),
#  ('merchant', 'NN'),
#  ('vessels', 'NNS'),
#  ('with', 'IN'),
#  ('the', 'DT'),
#  ('gently', 'RB'),
#  ('rolling', 'VBG'),
#  ('waters', 'NNS'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('bay', 'NN'),
#  ('of', 'IN'),
#  ('bengal', 'NN'),
#  ('scuffing', 'VBG'),
#  ('up', 'RP'),
#  ('under', 'IN'),
#  ('the', 'DT'),
#  ('prow', 'NN'),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('engines', 'NNS'),
#  ('at', 'IN'),
#  ('half', 'PDT'),
#  ('speed', 'NN'),
#  ('gradually', 'RB'),
#  ('bringing', 'VBG'),
#  ('the', 'DT'),
#  ('ship', 'NN'),
#  ('nearer', 'NN'),
#  ('and', 'CC'),
#  ('nearer', 'NN'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('wharves', 'NNS'),
#  ('of', 'IN'),
#  ('calcutta', 'NN'),
#  ('he', 'PRP'),
#  ('might', 'MD'),
#  ('have', 'VB'),
#  ('seemed', 'VBN'),
#  ('to', 'TO'),
#  ('strangers', 'NNS'),
#  ('to', 'TO'),
#  ('be', 'VB'),
#  ('a', 'DT'),
#  ('man', 'NN'),
#  ('to', 'TO'),
#  ('be', 'VB'),
#  ('envied', 'VBN'),
#  ('yet', 'RB'),
#  ('tearing', 'VBG'),
#  ('at', 'IN'),
#  ('his', 'PRP$'),
#  ('heart', 'NN'),
#  ('was', 'VBD'),
#  ('the', 'DT'),
#  ('greatest', 'JJS'),
#  ('anxiety', 'NN'),
#  ('he', 'PRP'),
#  ('ever', 'RB'),
#  ('had', 'VBD'),
#  ('known', 'VBN'),
#  ('the', 'DT'),
#  ('question', 'NN'),
#  ('whether', 'IN'),
#  ('his', 'PRP$'),
#  ('boy', 'NN'),
#  ('whom', 'WP'),
#  ('he', 'PRP'),
#  ('loved', 'VBD'),
#  ('better', 'JJR'),
#  ('than', 'IN'),
#  ('himself', 'PRP'),
#  ('was', 'VBD'),
#  ('dead', 'JJ'),
#  ('or', 'CC'),
#  ('living', 'VBG'),
#  ('the', 'DT'),
#  ('scene', 'NN'),
#  ('was', 'VBD'),
#  ('as', 'IN'),
#  ('beautiful', 'NN'),
#  ('a', 'DT'),
#  ('one', 'CD'),
#  ('as', 'IN'),
#  ('nature', 'NN'),
#  ('can', 'MD'),
#  ('produce', 'VB'),
#  ('in', 'IN'),
#  ('her', 'PRP'),
#  ('most', 'RBS'),
#  ('happy', 'JJ'),
#  ('mood', 'NN'),
#  ('the', 'DT'),
#  ('blue', 'NN'),
#  ('waves', 'VBZ'),
#  ('with', 'IN'),
#  ('their', 'PRP$'),
#  ('crests', 'NNS'),
#  ('the', 'DT'),
#  ('panorama', 'NN'),
#  ('of', 'IN'),
#  ('mountain', 'NN'),
#  ('and', 'CC'),
#  ('forest', 'NN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('distance', 'NN'),
#  ('still', 'RB'),
#  ('hazy', 'VBZ'),
#  ('as', 'IN'),
#  ('the', 'DT'),
#  ('mists', 'NNS'),
#  ('of', 'IN'),
#  ('early', 'JJ'),
#  ('morning', 'NN'),
#  ('hung', 'NN'),
#  ('before', 'IN'),
#  ('them', 'PRP'),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('big', 'JJ'),
#  ('city', 'NN'),
#  ('of', 'IN'),
#  ('calcutta', 'NN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('foreground', 'NN'),
#  ('its', 'PRP$'),
#  ('white', 'JJ'),
#  ('buildings', 'NNS'),
#  ('glistening', 'VBG'),
#  ('fairylike', 'NN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('glorious', 'JJ'),
#  ('sunlight', 'NN'),
#  ('all', 'DT'),
#  ('combined', 'VBN'),
#  ('to', 'TO'),
#  ('make', 'VB'),
#  ('the', 'DT'),
#  ('approach', 'NN'),
#  ('to', 'TO'),
#  ('this', 'DT'),
#  ('famous', 'JJ'),
#  ('asiatic', 'JJ'),
#  ('port', 'NN'),
#  ('one', 'CD'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('most', 'RBS'),
#  ('fascinating', 'JJ'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('world', 'NN'),
#  ('what', 'WP'),
#  ('s', 'VBZ'),
#  ('that', 'DT'),
#  ('boat', 'NN'),
#  ('coming', 'VBG'),
#  ('out', 'RP'),
#  ('suddenly', 'RB'),
#  ('exclaimed', 'VBD'),
#  ('jefferson', 'JJ'),
#  ('arnold', 'JJ'),
#  ('couldn', 'NN'),
#  ('t', 'NN'),
#  ('wait', 'NN'),
#  ('for', 'IN'),
#  ('us', 'PRP'),
#  ('to', 'TO'),
#  ('get', 'VB'),
#  ('alongside', 'IN'),
#  ('the', 'DT'),
#  ('wharf', 'JJ'),
#  ('eh', 'NN'),
#  ('we', 'PRP'),
#  ('re', 'VBP'),
#  ('five', 'CD'),
#  ('miles', 'NNS'),
#  ('from', 'IN'),
#  ('shore', 'NN'),
#  ('if', 'IN'),
#  ('not', 'RB'),
#  ('more', 'RBR'),
#  ('what', 'WP'),
#  ('do', 'VBP'),
#  ('you', 'PRP'),
#  ('make', 'VB'),
#  ('of', 'IN'),
#  ('it', 'PRP'),
#  ('captain', 'VBZ'),
#  ('he', 'PRP'),
#  ('added', 'VBD'),
#  ('in', 'IN'),
#  ('a', 'DT'),
#  ('louder', 'NN'),
#  ('tone', 'NN'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('skipper', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('who', 'WP'),
#  ('stood', 'VBD'),
#  ...]

# %%
def FrequencyDist(tags):
    wfd=FreqDist(t for (w, t) in tags)
    wfd
    wfd.plot(50)

# %%
 FrequencyDist(tagged1)

# %%
FrequencyDist(tagged2)
